# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (14,8)
import numpy as np 

directory = directory = "../gradient-values/"

ResNet18 = np.load((directory+"ResNet18.npy"))
ResNet34 = np.load((directory+"ResNet34.npy"))
ResNet50 = np.load((directory+"ResNet50.npy"))
DropoutResNet18 = np.load((directory+"Dropout-ResNet18.npy"))
DropoutResNet34 = np.load((directory+"Dropout-ResNet34.npy"))
DropoutResNet50 = np.load((directory+"Dropout-ResNet50.npy"))
BranchedResNet18 = np.load((directory+"BranchedResNet18.npy"))
BranchedResNet34 = np.load((directory+"BranchedResNet34.npy"))
BranchedResNet50 = np.load((directory+"BranchedResNet50.npy"))

GoogLeNet = np.load((directory+"GoogLeNet.npy"))
# Out:
# []

# %%
def plot(values,name):
    length = values[0].shape[0]
    layers = np.arange(length)
    count=0
    step=5
    for gradients in values[::step]:
      count = count + 1
      plt.plot(layers,gradients,label=("epoch:"+str(count*step)))

    plt.title("Layer-wise gradients in "+name)
    plt.ylabel("Average Gradient")
    plt.xlabel("Layer")
    plt.legend(loc='best')
    plt.savefig(('../results/CIFAR10/Weight Changes/'+name), bbox_inches = 'tight')
    plt.show()

# %%
plot(ResNet18,"ResNet18")
plot(DropoutResNet18,"ResNet18 with dropout")
plot(BranchedResNet18,"a branched ResNet18")

# %%
plot(ResNet34,"ResNet34")
plot(DropoutResNet34,"ResNet34 with dropout")
plot(BranchedResNet34,"a branched ResNet34")

# %%
plot(ResNet50,"ResNet50")
plot(DropoutResNet50,"ResNet50 with dropout")
plot(BranchedResNet50,"a branched ResNet50")

# %%
plot(GoogLeNet,"GoogLeNet")
